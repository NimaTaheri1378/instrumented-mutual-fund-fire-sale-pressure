# %% [markdown]
# # 00 Schema Audit
#
# Verify WRDS table mappings and inspect the frozen schema artifacts. Run the CLI stage on Amarel for live WRDS access.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve()
while not (ROOT / 'configs' / 'project.yml').exists():
    ROOT = ROOT.parent
print(ROOT)

# %%
import json
manifest = ROOT / 'manifests' / 'schema_audit.json'
if manifest.exists():
    audit = json.loads(manifest.read_text())
    print(audit['library_count'])
    display(pd.DataFrame(audit['tables']).T[['library', 'table', 'present', 'column_count']])
else:
    print('Run: python -m mffiresale.pipeline schema-audit --sample full')
