# %% [markdown]
# # 20 Baselines
#
# Review Fama-MacBeth, IV, DML, decile, placebo, and robustness outputs.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve()
while not (ROOT / 'configs' / 'project.yml').exists():
    ROOT = ROOT.parent
print(ROOT)

# %%
for name in ['raw_vs_instrumented_spreads_full.csv','iv_2sls_summary_full.csv','dml_iv_summary_full.csv','fama_macbeth_extended_full.csv','robustness_table_full.csv']:
    path = ROOT / 'reports' / 'tables' / name
    if path.exists():
        print('\n', name)
        display(pd.read_csv(path).head(20))
