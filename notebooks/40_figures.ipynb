# %% [markdown]
# # 40 Figures
#
# Open final PNG/SVG and Plotly HTML artifacts for visual QA.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve()
while not (ROOT / 'configs' / 'project.yml').exists():
    ROOT = ROOT.parent
print(ROOT)

# %%
from IPython.display import Image, display, HTML
fig_dir = ROOT / 'reports' / 'figures'
for name in ['cumulative_long_short_full.png','coverage_by_year_full.png','rolling_strategy_metrics_full.png','lightgbm_shap_summary_full.png']:
    path = fig_dir / name
    if path.exists():
        print(name)
        display(Image(filename=str(path)))

# %%
html_dir = ROOT / 'reports' / 'html'
for path in sorted(html_dir.glob('*.html')) if html_dir.exists() else []:
    print(path.name, path)
